# %%
import pandas as pd
from glob import glob

# %%
filenames = glob("*citibike-tripdata*.csv")

# %%
df = [pd.read_csv(f) for f in filenames]

# %%
dfs = pd.concat([df[0], df[1], df[2],df[3], df[4], df[5], df[6], df[7], df[8],df[9], df[10], df[11],df[12],df[13], df[14], df[15],df[16], df[17], df[18],df[19], df[20], df[21],df[22], df[23], df[24], df[25],df[26], df[27], df[28],df[29], df[30], df[31],df[32],df[33], df[34], df[35],df[36], df[37], df[38],df[39], df[40], df[41],df[42],df[43], df[44] ], sort=False, ignore_index = True)

# %%
dfs.head(20)
# Out:
#     Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0           362.0  2016-01-01 00:02:52  2016-01-01 00:08:54            3186.0
# 1           200.0  2016-01-01 00:18:22  2016-01-01 00:21:42            3186.0
# 2           202.0  2016-01-01 00:18:25  2016-01-01 00:21:47            3186.0
# 3           248.0  2016-01-01 00:23:13  2016-01-01 00:27:21            3209.0
# 4           903.0  2016-01-01 01:03:20  2016-01-01 01:18:24            3195.0
# 5           883.0  2016-01-01 01:03:28  2016-01-01 01:18:11            3195.0
# 6           445.0  2016-01-01 01:07:45  2016-01-01 01:15:11            3186.0
# 7           192.0  2016-01-01 01:18:51  2016-01-01 01:22:03            3211.0
# 8           409.0  2016-01-01 01:23:44  2016-01-01 01:30:34            3187.0
# 9           285.0  2016-01-01 01:25:12  2016-01-01 01:29:57            3187.0
# 10          206.0  2016-01-01 01:45:34  2016-01-01 01:49:00            3183.0
# ...

# %%
dfs.tail(20)
# Out:
#          Trip Duration Start Time Stop Time  Start Station ID  \
# 1208553            NaN        NaN       NaN               NaN
# 1208554            NaN        NaN       NaN               NaN
# 1208555            NaN        NaN       NaN               NaN
# 1208556            NaN        NaN       NaN               NaN
# 1208557            NaN        NaN       NaN               NaN
# 1208558            NaN        NaN       NaN               NaN
# 1208559            NaN        NaN       NaN               NaN
# 1208560            NaN        NaN       NaN               NaN
# 1208561            NaN        NaN       NaN               NaN
# 1208562            NaN        NaN       NaN               NaN
# 1208563            NaN        NaN       NaN               NaN
# 1208564            NaN        NaN       NaN               NaN
# 1208565            NaN        NaN       NaN               NaN
# 1208566            NaN        NaN       NaN               NaN
# ...

# %%
df[13] + df[14]
# Out:
#        Trip Duration                              Start Time  \
# 0             1511.0  2017-02-01 00:06:332017-03-01 00:03:02
# 1             1757.0  2017-02-01 01:02:212017-03-01 00:09:02
# 2             1934.0  2017-02-01 01:56:052017-03-01 00:28:11
# 3              797.0  2017-02-01 04:38:422017-03-01 00:52:30
# 4             2615.0  2017-02-01 04:42:222017-03-01 00:54:40
# 5             1287.0  2017-02-01 04:44:452017-03-01 01:02:28
# 6             1112.0  2017-02-01 05:16:362017-03-01 03:08:07
# 7              276.0  2017-02-01 05:20:382017-03-01 03:35:44
# 8              337.0  2017-02-01 05:35:312017-03-01 03:38:03
# 9              343.0  2017-02-01 05:55:182017-03-01 04:43:05
# 10             390.0  2017-02-01 05:58:092017-03-01 04:43:55
# 11             385.0  2017-02-01 06:02:342017-03-01 04:44:54
# 12             839.0  2017-02-01 06:08:152017-03-01 05:12:55
# 13             527.0  2017-02-01 06:10:302017-03-01 05:16:16
# ...

# %%
#filenames = []
#filenames2016 = glob("/*citibike-tripdata*.csv")
#filenames2017 = glob("/2017-citibike-tripdata/*citibike-tripdata*.csv")

# %%
pwd

# %%
filenames = glob("*citibike-tripdata*.csv")
#filenames2017 = glob("../2017-citibike-tripdata/*citibike-tripdata*.csv")
#filenames2018 = glob("../2018-citibike-tripdata/*citibike-tripdata*.csv")
#filenames2019 = glob("../2019-citibike-tripdata/*citibike-tripdata*.csv")

# %%
#df2016 = [pd.read_csv(f) for f in filenames2016]
#df2017 = [pd.read_csv(f) for f in filenames2017]
#df2018 = [pd.read_csv(f) for f in filenames2018]
#df2019 = [pd.read_csv(f) for f in filenames2019]

# %%
df2016

# %%
df2016 = pd.concat([df2016[0], df2016[1], df2016[2],df2016[3], df2016[4], df2016[5],df2016[6], df2016[7], df2016[8],df2016[9], df2016[10], df2016[11]], ignore_index = True)

# %%
pwd

# %%
#new_table_list = [f[:-3] for f in filenames]
dfs = [pd.read_csv(f) for f in filenames]

# %%
df2016 = pd.concat(dfs, ignore_index = True)

# %%
df2016.head(20)

# %%
df2016.tail(20)

# %%
df2017 = pd.concat([dfs[12], dfs[13], dfs[14],dfs[15], dfs[16], dfs[17],dfs[18], dfs[19], dfs[20],dfs[21], dfs[22], dfs[23]],  ignore_index = True)

# %%
df2017

# %%
file1= dfs[1]
file1.isnull().any()

# %%
file2= dfs[2]
file2.isnull().any()

# %%
df = pd.concat([file1, file2], ignore_index = True)

# %%
df

# %%
#pd.concat(dfs[0], dfs[1], ignore_index = True)
#citibike_tripdata_2016_clean.to_csv("CitibikeTripdata2016.csv", index=False)

# %%
usertype3 = data3['usertype']

# %%
df = pd.concat(dfs, ignore_index = True)

# %%
dfs[0]

# %%
len(dfs)
